# %% [markdown]
# # Dataset 1

# %% [markdown]
# Let's import numpy and pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading the csv and storing the data of csv in data variable

# %%
data = pd.read_csv("/content/Data-cleaning-for-beginners-using-pandas.csv")

# %% [markdown]
# Displaying the first 10 rows of data

# %%
data.head(10)
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1
# 5      5  44.0  $77k-$89k     1.4       India,In         1999       TRUE
# 6      6  21.0  $44k-$99k     0.0    New York,Ny           -1         -1
# 7      7  44.0  $44k-$99k    -1.0  Australia Aus           -1         -1
# 8      8  35.0  $44k-$99k     5.4    New York,Ny           -1         -1
# 9      9  22.0  $44k-$99k     7.7       India,In           -1       TRUE

# %% [markdown]
# Checking how many rows and columns the data has

# %%
data.shape
# Out:
# (29, 7)

# %% [markdown]
# gaining some information about dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# displaying the column name

# %%
data.columns
# Out:
# Index(['Index', 'Age', 'Salary', 'Rating', 'Location', 'Established',
#        'Easy Apply'],
#       dtype='object')

# %% [markdown]
# checking for the missing values/NULL values

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %% [markdown]
# Using mean() of Age column we can handle the missing values of Age column

# %%
avg_age = data["Age"].mean()

# %%
avg_age
# Out:
# 39.04545454545455

# %% [markdown]
# by using fillna() we successfully filled avg values of Age to null values

# %%
data["Age"] = data["Age"].fillna(avg_age)

# %%
data["Age"]
# Out:
# 0     44.000000
# 1     66.000000
# 2     39.045455
# 3     64.000000
# 4     25.000000
# 5     44.000000
# 6     21.000000
# 7     44.000000
# 8     35.000000
# 9     22.000000
# 10    55.000000
# 11    44.000000
# 12    39.045455
# 13    25.000000
# 14    66.000000
# 15    44.000000
# 16    19.000000
# 17    39.045455
# 18    35.000000
# 19    32.000000
# 20    39.045455
# 21    35.000000
# 22    19.000000
# 23    39.045455
# 24    13.000000
# 25    55.000000
# 26    39.045455
# 27    52.000000
# 28    39.045455
# Name: Age, dtype: float64

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            0
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data
# Out:
#     Index        Age      Salary  Rating       Location  Established  \
# 0       0  44.000000   $44k-$99k     5.4       India,In         1999
# 1       1  66.000000   $55k-$66k     3.5    New York,Ny         2002
# 2       2  39.045455   $77k-$89k    -1.0    New York,Ny           -1
# 3       3  64.000000   $44k-$99k     4.4       India In         1988
# 4       4  25.000000   $44k-$99k     6.4  Australia Aus         2002
# 5       5  44.000000   $77k-$89k     1.4       India,In         1999
# 6       6  21.000000   $44k-$99k     0.0    New York,Ny           -1
# 7       7  44.000000   $44k-$99k    -1.0  Australia Aus           -1
# 8       8  35.000000   $44k-$99k     5.4    New York,Ny           -1
# 9       9  22.000000   $44k-$99k     7.7       India,In           -1
# 10     10  55.000000   $10k-$49k     5.4       India,In         2008
# 11     11  44.000000   $10k-$49k     6.7       India,In         2009
# 12     12  39.045455   $44k-$99k     0.0       India,In         1999
# ...

# %% [markdown]
# Rounding to one decimal place

# %%
data["Age"]=data["Age"].round(decimals=1)

# %% [markdown]
# Calculating the mean of Rating column

# %%
avg_rating=data["Rating"].mean()

# %%
avg_rating
# Out:
# 3.528571428571429

# %% [markdown]
# Filling the null values with mean values

# %%
data["Rating"]=data["Rating"].fillna(avg_rating)

# %%
data["Rating"]
# Out:
# 0     5.400000
# 1     3.500000
# 2    -1.000000
# 3     4.400000
# 4     6.400000
# 5     1.400000
# 6     0.000000
# 7    -1.000000
# 8     5.400000
# 9     7.700000
# 10    5.400000
# 11    6.700000
# 12    0.000000
# 13   -1.000000
# 14    4.000000
# 15    3.000000
# 16    4.500000
# 17    5.300000
# 18    6.700000
# 19    3.300000
# 20    5.700000
# 21    5.000000
# 22    7.800000
# 23    2.400000
# 24   -1.000000
# 25    0.000000
# 26    3.528571
# 27    5.400000
# 28    3.400000
# Name: Rating, dtype: float64

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            0
# Salary         0
# Rating         0
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %% [markdown]
# No null values left!

# %% [markdown]
# Now , by observing the data we know that there are negative values in Rating column

# %% [markdown]
# Replacing the negative values to null values

# %%
data["Rating"]=data["Rating"].replace(-1.000000,np.nan)

# %%
data["Rating"]
# Out:
# 0     5.400000
# 1     3.500000
# 2          NaN
# 3     4.400000
# 4     6.400000
# 5     1.400000
# 6     0.000000
# 7          NaN
# 8     5.400000
# 9     7.700000
# 10    5.400000
# 11    6.700000
# 12    0.000000
# 13         NaN
# 14    4.000000
# 15    3.000000
# 16    4.500000
# 17    5.300000
# 18    6.700000
# 19    3.300000
# 20    5.700000
# 21    5.000000
# 22    7.800000
# 23    2.400000
# 24         NaN
# 25    0.000000
# 26    3.528571
# 27    5.400000
# 28    3.400000
# Name: Rating, dtype: float64

# %% [markdown]
# Replacing null values with mean

# %%
data["Rating"]=data["Rating"].fillna(avg_rating)

# %%
data["Rating"]
# Out:
# 0     5.400000
# 1     3.500000
# 2     3.528571
# 3     4.400000
# 4     6.400000
# 5     1.400000
# 6     0.000000
# 7     3.528571
# 8     5.400000
# 9     7.700000
# 10    5.400000
# 11    6.700000
# 12    0.000000
# 13    3.528571
# 14    4.000000
# 15    3.000000
# 16    4.500000
# 17    5.300000
# 18    6.700000
# 19    3.300000
# 20    5.700000
# 21    5.000000
# 22    7.800000
# 23    2.400000
# 24    3.528571
# 25    0.000000
# 26    3.528571
# 27    5.400000
# 28    3.400000
# Name: Rating, dtype: float64

# %%
data["Rating"] = data["Rating"].round(decimals=1)

# %%
data["Rating"]
# Out:
# 0     5.4
# 1     3.5
# 2     3.5
# 3     4.4
# 4     6.4
# 5     1.4
# 6     0.0
# 7     3.5
# 8     5.4
# 9     7.7
# 10    5.4
# 11    6.7
# 12    0.0
# 13    3.5
# 14    4.0
# 15    3.0
# 16    4.5
# 17    5.3
# 18    6.7
# 19    3.3
# 20    5.7
# 21    5.0
# 22    7.8
# 23    2.4
# 24    3.5
# 25    0.0
# 26    3.5
# 27    5.4
# 28    3.4
# Name: Rating, dtype: float64

# %%
data
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2  39.0   $77k-$89k     3.5    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k     3.5  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.dtypes
# Out:
# Index            int64
# Age            float64
# Salary          object
# Rating         float64
# Location        object
# Established      int64
# Easy Apply      object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          29 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       29 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# Finding outliers in Age and Rating columns

# %%
Outlier = ['Age','Rating']
for i in Outlier:
    Q1 = data[i].quantile(0.25)
    Q3 = data[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data[i] < lower_bound) | (data[i] > upper_bound)]

    print(f"Potential Outliers in {i}: ")
    print(outliers)
# Out:
# Potential Outliers in Age:
#     Index   Age     Salary  Rating       Location  Established Easy Apply
# 1       1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 3       3  64.0  $44k-$99k     4.4       India In         1988         -1
# 14     14  66.0  $44k-$99k     4.0  Australia Aus         2020       TRUE
# 24     24  13.0  $44k-$99k     3.5    New York,Ny         1987         -1
# Potential Outliers in Rating:
#     Index   Age     Salary  Rating       Location  Established Easy Apply
# 6       6  21.0  $44k-$99k     0.0    New York,Ny           -1         -1
# 12     12  39.0  $44k-$99k     0.0       India,In         1999         -1
# 25     25  55.0  $44k-$99k     0.0  Australia Aus         1980       TRUE

# %% [markdown]
# Converting Age column into integer datatype

# %%
data["Age"]=data['Age'].astype(int)

# %%
data["Age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 29 entries, 0 to 28
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 29 non-null     int64
# dtypes: int64(1)
# memory usage: 360.0 bytes

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            0
# Salary         0
# Rating         0
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %% [markdown]
# Now dataset does not have any null values

# %%
data.head()
# Out:
#    Index  Age     Salary  Rating       Location  Established Easy Apply
# 0      0   44  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1   66  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   39  $77k-$89k     3.5    New York,Ny           -1         -1
# 3      3   64  $44k-$99k     4.4       India In         1988         -1
# 4      4   25  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data["Salary"] = data["Salary"].str.replace("$","",regex=True)
data["Salary"] = data["Salary"].str.replace("k","000")

# %%
data["Salary"]
# Out:
# 0      44000-99000
# 1      55000-66000
# 2      77000-89000
# 3      44000-99000
# 4      44000-99000
# 5      77000-89000
# 6      44000-99000
# 7      44000-99000
# 8      44000-99000
# 9      44000-99000
# 10     10000-49000
# 11     10000-49000
# 12     44000-99000
# 13     44000-99000
# 14     44000-99000
# 15    88000-101000
# 16     19000-40000
# 17     44000-99000
# 18     44000-99000
# 19     44000-99000
# 20     44000-99000
# 21     44000-99000
# 22     55000-66000
# 23     44000-99000
# 24     44000-99000
# 25     44000-99000
# 26     55000-66000
# 27     44000-99000
# 28     39000-88000
# Name: Salary, dtype: object

# %% [markdown]
# Separing the values into Min and Max salary using - as separater

# %%
data["Salary"]=data["Salary"].str.split("-")

# %%
data["Min-Salary"]=data["Salary"].str[0]
data["Max-Salary"]=data["Salary"].str[1]

# %%
data.head()
# Out:
#    Index  Age          Salary  Rating       Location  Established Easy Apply  \
# 0      0   44  [44000, 99000]     5.4       India,In         1999       TRUE
# 1      1   66  [55000, 66000]     3.5    New York,Ny         2002       TRUE
# 2      2   39  [77000, 89000]     3.5    New York,Ny           -1         -1
# 3      3   64  [44000, 99000]     4.4       India In         1988         -1
# 4      4   25  [44000, 99000]     6.4  Australia Aus         2002         -1
#
#   Min-Salary Max-Salary
# 0      44000      99000
# 1      55000      66000
# 2      77000      89000
# 3      44000      99000
# 4      44000      99000

# %%
data=data.drop(columns=["Salary"])

# %%
data.head()
# Out:
#    Index  Age  Rating       Location  Established Easy Apply Min-Salary  \
# 0      0   44     5.4       India,In         1999       TRUE      44000
# 1      1   66     3.5    New York,Ny         2002       TRUE      55000
# 2      2   39     3.5    New York,Ny           -1         -1      77000
# 3      3   64     4.4       India In         1988         -1      44000
# 4      4   25     6.4  Australia Aus         2002         -1      44000
#
#   Max-Salary
# 0      99000
# 1      66000
# 2      89000
# 3      99000
# 4      99000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          29 non-null     int64
#  2   Rating       29 non-null     float64
#  3   Location     29 non-null     object
#  4   Established  29 non-null     int64
#  5   Easy Apply   29 non-null     object
#  6   Min-Salary   29 non-null     object
#  7   Max-Salary   29 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.9+ KB

# %%
data["Min-Salary"]=data["Min-Salary"].astype(int)
data["Max-Salary"]=data["Max-Salary"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          29 non-null     int64
#  2   Rating       29 non-null     float64
#  3   Location     29 non-null     object
#  4   Established  29 non-null     int64
#  5   Easy Apply   29 non-null     object
#  6   Min-Salary   29 non-null     int64
#  7   Max-Salary   29 non-null     int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 1.9+ KB

# %%
data.head(10)
# Out:
#    Index  Age  Rating       Location  Established Easy Apply  Min-Salary  \
# 0      0   44     5.4       India,In         1999       TRUE       44000
# 1      1   66     3.5    New York,Ny         2002       TRUE       55000
# 2      2   39     3.5    New York,Ny           -1         -1       77000
# 3      3   64     4.4       India In         1988         -1       44000
# 4      4   25     6.4  Australia Aus         2002         -1       44000
# 5      5   44     1.4       India,In         1999       TRUE       77000
# 6      6   21     0.0    New York,Ny           -1         -1       44000
# 7      7   44     3.5  Australia Aus           -1         -1       44000
# 8      8   35     5.4    New York,Ny           -1         -1       44000
# 9      9   22     7.7       India,In           -1       TRUE       44000
#
#    Max-Salary
# 0       99000
# 1       66000
# 2       89000
# 3       99000
# 4       99000
# 5       89000
# 6       99000
# 7       99000
# 8       99000
# ...

# %%
data["Location"]=data["Location"].str.split(",").str[0]

# %%
data["Location"] = data["Location"].str.replace(" Aus","")
data["Location"] = data["Location"].str.replace(" In","")

# %%
data["Location"]
# Out:
# 0         India
# 1      New York
# 2      New York
# 3         India
# 4     Australia
# 5         India
# 6      New York
# 7     Australia
# 8      New York
# 9         India
# 10        India
# 11        India
# 12        India
# 13    Australia
# 14    Australia
# 15    Australia
# 16        India
# 17     New York
# 18     New York
# 19     New York
# 20     New York
# 21     New York
# 22     New York
# 23     New York
# 24     New York
# 25    Australia
# 26        India
# 27        India
# 28    Australia
# Name: Location, dtype: object

# %%
data.head()
# Out:
#    Index  Age  Rating   Location  Established Easy Apply  Min-Salary  \
# 0      0   44     5.4      India         1999       TRUE       44000
# 1      1   66     3.5   New York         2002       TRUE       55000
# 2      2   39     3.5   New York           -1         -1       77000
# 3      3   64     4.4      India         1988         -1       44000
# 4      4   25     6.4  Australia         2002         -1       44000
#
#    Max-Salary
# 0       99000
# 1       66000
# 2       89000
# 3       99000
# 4       99000

# %%
data["Established"] = data["Established"].replace(-1,np.nan)

# %%
data["Established"].head()
# Out:
# 0    1999.0
# 1    2002.0
# 2       NaN
# 3    1988.0
# 4    2002.0
# Name: Established, dtype: float64

# %%
data["Easy Apply"] = data["Easy Apply"].replace("-1","FALSE")

# %%
data["Easy Apply"]
# Out:
# 0      TRUE
# 1      TRUE
# 2     FALSE
# 3     FALSE
# 4     FALSE
# 5      TRUE
# 6     FALSE
# 7     FALSE
# 8     FALSE
# 9      TRUE
# 10     TRUE
# 11    FALSE
# 12    FALSE
# 13     TRUE
# 14     TRUE
# 15    FALSE
# 16    FALSE
# 17     TRUE
# 18     TRUE
# 19     TRUE
# 20     TRUE
# 21    FALSE
# 22     TRUE
# 23     TRUE
# 24    FALSE
# 25     TRUE
# 26     TRUE
# 27    FALSE
# 28    FALSE
# Name: Easy Apply, dtype: object

# %%
data.head(4)
# Out:
#    Index  Age  Rating  Location  Established Easy Apply  Min-Salary  \
# 0      0   44     5.4     India       1999.0       TRUE       44000
# 1      1   66     3.5  New York       2002.0       TRUE       55000
# 2      2   39     3.5  New York          NaN      FALSE       77000
# 3      3   64     4.4     India       1988.0      FALSE       44000
#
#    Max-Salary
# 0       99000
# 1       66000
# 2       89000
# 3       99000

# %%
data[["Established","Age"]]
# Out:
#     Established  Age
# 0        1999.0   44
# 1        2002.0   66
# 2           NaN   39
# 3        1988.0   64
# 4        2002.0   25
# 5        1999.0   44
# 6           NaN   21
# 7           NaN   44
# 8           NaN   35
# 9           NaN   22
# 10       2008.0   55
# 11       2009.0   44
# 12       1999.0   39
# 13       2019.0   25
# 14       2020.0   66
# 15       1999.0   44
# 16       1984.0   19
# 17       1943.0   39
# 18       1954.0   35
# 19       1955.0   32
# 20       1944.0   39
# 21       1946.0   35
# 22       1988.0   19
# 23       1999.0   39
# 24       1987.0   13
# 25       1980.0   55
# 26       1934.0   39
# 27       1935.0   52
# 28       1932.0   39

# %%
data
# Out:
#     Index  Age  Rating   Location  Established Easy Apply  Min-Salary  \
# 0       0   44     5.4      India       1999.0       TRUE       44000
# 1       1   66     3.5   New York       2002.0       TRUE       55000
# 2       2   39     3.5   New York          NaN      FALSE       77000
# 3       3   64     4.4      India       1988.0      FALSE       44000
# 4       4   25     6.4  Australia       2002.0      FALSE       44000
# 5       5   44     1.4      India       1999.0       TRUE       77000
# 6       6   21     0.0   New York          NaN      FALSE       44000
# 7       7   44     3.5  Australia          NaN      FALSE       44000
# 8       8   35     5.4   New York          NaN      FALSE       44000
# 9       9   22     7.7      India          NaN       TRUE       44000
# 10     10   55     5.4      India       2008.0       TRUE       10000
# 11     11   44     6.7      India       2009.0      FALSE       10000
# ...

# %% [markdown]
# After successfully cleaning the dataset and resolving any inconsistencies, and converting categorical values into numerical values through techniques like OneHotEncoding etc, The data set will be ready for training the ML model :)

# %%
data1=pd.read_csv("/content/Data-cleaning-for-beginners-using-pandas.csv")

# %% [markdown]
# **Answering all the questions below which were given in the document.**

# %% [markdown]
# 1. **Missing Values:**
#
# Question: Are there any missing values in the dataset, and if so, how should they be handled for each indicator?
#
#
# Answer: By using  data.isnull().sum() we  come to know that **Yes** There are missing values present in the dataset. Age col is having 7 missing values and Rating currently have only one. By calculating mean of numerical column we can replace null values with mean.

# %%
data1.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %% [markdown]
# 2. **Data Types**:
#
# Question: What are the data types of each indicator, and do they align with their expected types (e.g., numerical, categorical)?
#
#  Answer : Age and Salary must be of integer datatype

# %%
data1.dtypes
# Out:
# Index            int64
# Age            float64
# Salary          object
# Rating         float64
# Location        object
# Established      int64
# Easy Apply      object
# dtype: object

# %% [markdown]
# 3. **Outliers**:
#
# Question: Identify potential outliers in numerical indicators (e.g., Age, Salary, Rating). Should outliers be removed or adjusted?

# %%
Outlier = ['Age','Rating']
for i in Outlier:
    Q1 = data1[i].quantile(0.25)
    Q3 = data1[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data1[(data1[i] < lower_bound) | (data1[i] > upper_bound)]

    print(f"Potential Outliers in {i}: ")
    print(outliers)
    ## After performing operations on Rating column we get 0.0 as the outlier present there
# Out:
# Potential Outliers in Age:
#     Index   Age       Salary  Rating   Location  Established Easy Apply
# 1       1  66.0  55000-66000     3.5   New York       2002.0       TRUE
# 3       3  64.0  44000-99000     4.4      India       1988.0      FALSE
# 14     14  66.0  44000-99000     4.0  Australia       2020.0       TRUE
# 24     24  13.0  44000-99000     1.0   New York       1987.0      FALSE
# Potential Outliers in Rating:
# Empty DataFrame
# Columns: [Index, Age, Salary, Rating, Location, Established, Easy Apply]
# Index: []

# %% [markdown]
# 4. **Salary Formatting**:
#
# Question: Examine the format of the Salary column. Does it require any formatting or standardization for consistent analysis?
#
# Answer: Yes it requires formatting for consistent analysis. Eliminating the symbols '$' and 'k' from the salary values will contribute to refining our dataset.

# %%
data1["Salary"] = data1["Salary"].str.replace("$","",regex=True)
data1["Salary"] = data1["Salary"].str.replace("k","000")
data1["Salary"]
# Out:
# 0      44000-99000
# 1      55000-66000
# 2      77000-89000
# 3      44000-99000
# 4      44000-99000
# 5      77000-89000
# 6      44000-99000
# 7      44000-99000
# 8      44000-99000
# 9      44000-99000
# 10     10000-49000
# 11     10000-49000
# 12     44000-99000
# 13     44000-99000
# 14     44000-99000
# 15    88000-101000
# 16     19000-40000
# 17     44000-99000
# 18     44000-99000
# 19     44000-99000
# 20     44000-99000
# 21     44000-99000
# 22     55000-66000
# 23     44000-99000
# 24     44000-99000
# 25     44000-99000
# 26     55000-66000
# 27     44000-99000
# 28     39000-88000
# Name: Salary, dtype: object

# %% [markdown]
# 5. **Location Standardization**:
#
# Question: Check the consistency of location entries. Do they need standardization, and how can this be achieved?
#
# Answer: Yes there are inconsistent values in Location column. By splitting , we can achieve the consistent values

# %%
data1["Location"]=data1["Location"].str.split(",").str[0]

# %% [markdown]
# 6. **Established Column**:
#
# Question: Explore the Established column. Are there any inconsistencies or anomalies that need to be addressed?
#
# Answer: Yes there are negative values in Establish column which create inconsistency

# %%
data1["Established"] = data1["Established"].replace(-1,np.nan)

# %% [markdown]
# 7. **Easy Apply Indicator**:
#
# Question: Analyze the Easy Apply column. Does it contain boolean values or need transformation for better analysis?
#
# Answer: It contains True and -1 , need to transform for better analysis

# %% [markdown]
# 8. **Rating Range**:
#
# Question: Investigate the range of values in the Rating column. Does it fall within expected rating scales, and how should outliers be treated?

# %%
data1['Rating'] = data1.Rating.round(decimals = 1).abs()

# %% [markdown]
# 9. **Age Distribution**:
# Question: Check the distribution of values in the Age column. Are there any unusual entries, and how might they impact analysis?

# %%
avg_age=data1["Age"].mean()
data1["Age"] = data1["Age"].fillna(avg_age)

# %% [markdown]
# 10. **Handling Special Characters**:
#
# Question: Examine all text-based columns (e.g., Location). Are there special characters or inconsistencies that need cleaning?
#
# Location have space and comma

# %%
data1["Location"] = data1["Location"].str.replace(" Aus","")
data1["Location"] = data1["Location"].str.replace(" In","")

# %%
data1["Location"]
# Out:
# 0         India
# 1      New York
# 2      New York
# 3         India
# 4     Australia
# 5         India
# 6      New York
# 7     Australia
# 8      New York
# 9         India
# 10        India
# 11        India
# 12        India
# 13    Australia
# 14    Australia
# 15    Australia
# 16        India
# 17     New York
# 18     New York
# 19     New York
# 20     New York
# 21     New York
# 22     New York
# 23     New York
# 24     New York
# 25    Australia
# 26        India
# 27        India
# 28    Australia
# Name: Location, dtype: object

# %% [markdown]
# 11. **Data Integrity:**
#
# Question: Ensure data integrity by cross-referencing entries. For instance, does the Established column align with the Age column?

# %%
data1[["Established","Age"]]
# Out:
#     Established        Age
# 0        1999.0  44.000000
# 1        2002.0  66.000000
# 2           NaN  39.045455
# 3        1988.0  64.000000
# 4        2002.0  25.000000
# 5        1999.0  44.000000
# 6           NaN  21.000000
# 7           NaN  44.000000
# 8           NaN  35.000000
# 9           NaN  22.000000
# 10       2008.0  55.000000
# 11       2009.0  44.000000
# 12       1999.0  39.045455
# 13       2019.0  25.000000
# 14       2020.0  66.000000
# 15       1999.0  44.000000
# 16       1984.0  19.000000
# 17       1943.0  39.045455
# 18       1954.0  35.000000
# 19       1955.0  32.000000
# 20       1944.0  39.045455
# 21       1946.0  35.000000
# 22       1988.0  19.000000
# 23       1999.0  39.045455
# 24       1987.0  13.000000
# 25       1980.0  55.000000
# 26       1934.0  39.045455
# 27       1935.0  52.000000
# 28       1932.0  39.045455

# %% [markdown]
# 12. **Easy Apply Transformation**:
#
# Question: If the Easy Apply column contains non-boolean values, how can it be transformed into a usable format?
#
#  Answer: By replacing -1 to FALSE

# %%
data1["Easy Apply"] = data1["Easy Apply"].replace("-1","FALSE")

# %% [markdown]
# 13. **Location Accuracy**:
# Question: Assess the accuracy of location entries. Are there misspelled or ambiguous locations that require correction?
#
# Answer: No , after performing split() now currently location col have correct values. In previous data corrections were required!

# %%
data1.head()
# Out:
#    Index        Age       Salary  Rating   Location  Established Easy Apply
# 0      0  44.000000  44000-99000     5.4      India       1999.0       TRUE
# 1      1  66.000000  55000-66000     3.5   New York       2002.0       TRUE
# 2      2  39.045455  77000-89000     1.0   New York          NaN      FALSE
# 3      3  64.000000  44000-99000     4.4      India       1988.0      FALSE
# 4      4  25.000000  44000-99000     6.4  Australia       2002.0      FALSE

# %% [markdown]
# 14. **Handling Categorical Data**:
#
# Question: For categorical indicators, consider encoding or transforming them into a format suitable for analysis.
#
# Answer: For conversion of categorical values into numericl values, we require techniques like OneHotEncoding, Label encoder.

# %% [markdown]
# 15. **Consistent Rating Scale**:
#
# Question: Ensure a consistent rating scale in the Rating column. Should it be normalized or adjusted for uniform analysis?

# %%
avg_rating=data1["Rating"].mean()
data1["Rating"]=data1["Rating"].fillna(avg_rating)

# %%
data1.head()
# Out:
#    Index        Age       Salary  Rating   Location  Established Easy Apply
# 0      0  44.000000  44000-99000     5.4      India       1999.0       TRUE
# 1      1  66.000000  55000-66000     3.5   New York       2002.0       TRUE
# 2      2  39.045455  77000-89000     1.0   New York          NaN      FALSE
# 3      3  64.000000  44000-99000     4.4      India       1988.0      FALSE
# 4      4  25.000000  44000-99000     6.4  Australia       2002.0      FALSE
